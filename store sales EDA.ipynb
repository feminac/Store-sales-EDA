# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales=pd.read_csv(r'C:\Users\femif\Downloads\supermarket.csv\supermarket.csv')
sales
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# # number of columns and rows

# %%
sales.shape
# Out:
# (9800, 18)

# %% [markdown]
# # Number of elemnts

# %%
sales.size
# Out:
# 176400

# %%
##information
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %% [markdown]
# # Display the first few rows from this dataset

# %%
sales.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
sales.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 5       6  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 6       7  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 7       8  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 8       9  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
# 9      10  CA-2015-115812  09/06/2015  14/06/2015  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City       State  \
# ...

# %%
##Discriptive Analysis

sales.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %% [markdown]
# # Detect duplicate

# %%
sales[sales.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales]
# Index: []

# %% [markdown]
# There are no duplicated values

# %% [markdown]
# # Null values

# %%
sales.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
sales[sales['Postal Code'].isnull()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %% [markdown]
# # Display columns

# %%
sales.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
#checking ship mode details
df=sales['Ship Mode'].value_counts()
df
# Out:
# Standard Class    5859
# Second Class      1902
# First Class       1501
# Same Day           538
# Name: Ship Mode, dtype: int64

# %%
df.max()
# Out:
# 5859

# %%
sales['Ship Mode'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sales['Ship Mode'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Ship Mode'>

# %% [markdown]
# The highest level is standerd class and the lowest level is on the same days

# %%
#cheking segment details
sales['Segment'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sales['Segment'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Segment'>

# %%
#checking country details
sales['Country'].value_counts()
# Out:
# United States    9800
# Name: Country, dtype: int64

# %% [markdown]
# This datasets contains only united states store sales details

# %%
sales['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
sales['City'].nunique()
# Out:
# 529

# %%
sales['City'].value_counts()
# Out:
# New York City    891
# Los Angeles      728
# Philadelphia     532
# San Francisco    500
# Seattle          426
#                 ...
# San Mateo          1
# Cheyenne           1
# Conway             1
# Melbourne          1
# Springdale         1
# Name: City, Length: 529, dtype: int64

# %%
sns.countplot(x='Ship Mode',data=sales)
plt.title('Ship Mode')
# Out:
# Text(0.5, 1.0, 'Ship Mode')

# %%
#checking state deatilssales['State'].value_counts()
sales['State'].nunique()
# Out:
# 49

# %%
sales['State'].value_counts()
# Out:
# California              1946
# New York                1097
# Texas                    973
# Pennsylvania             582
# Washington               504
# Illinois                 483
# Ohio                     454
# Florida                  373
# Michigan                 253
# North Carolina           247
# Virginia                 224
# Arizona                  223
# Tennessee                183
# Colorado                 179
# Georgia                  177
# Kentucky                 137
# Indiana                  135
# Massachusetts            135
# Oregon                   122
# New Jersey               122
# Maryland                 105
# Wisconsin                105
# Delaware                  93
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              55
# Mississippi               53
# Utah                      53
# ...

# %%
plt.figure(figsize=(18,8))
plt.xticks(rotation=87)
sns.countplot(x='State',data=sales)
# Out:
# <Axes: xlabel='State', ylabel='count'>

# %%
#checking category
sales['Category'].value_counts()
# Out:
# Office Supplies    5909
# Furniture          2078
# Technology         1813
# Name: Category, dtype: int64

# %%
sales['Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# The biggest supplies is office supplies

# %%
# Plotting ship mode with respect to category.
plt.figure(figsize = (10,4))
sns.countplot(data = sales, x = "Ship Mode",  hue = "Category")
plt.title("Ship Mode level")
plt.xlabel("Ship Mode")
plt.legend(["Office Supplies", " Furniture", "Technology"])

# %%
sales['Sales'].value_counts()
# Out:
# 9800

# %%
#checking product name
sales['Product Name'].value_counts()
# Out:
# Staple envelope                                                        47
# Staples                                                                46
# Easy-staple paper                                                      44
# Avery Non-Stick Binders                                                20
# Staples in misc. colors                                                18
#                                                                        ..
# Xiaomi Mi3                                                              1
# Universal Ultra Bright White Copier/Laser Paper, 8 1/2" x 11", Ream     1
# Socket Bluetooth Cordless Hand Scanner (CHS)                            1
# Logitech Illuminated Ultrathin Keyboard with Backlighting               1
# LG G2                                                                   1
# Name: Product Name, Length: 1849, dtype: int64

# %%
sales
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
#checking sub category
sales['Sub-Category'].value_counts()
# Out:
# Binders        1492
# Paper          1338
# Furnishings     931
# Phones          876
# Storage         832
# Art             785
# Accessories     756
# Chairs          607
# Appliances      459
# Labels          357
# Tables          314
# Envelopes       248
# Bookcases       226
# Fasteners       214
# Supplies        184
# Machines        115
# Copiers          66
# Name: Sub-Category, dtype: int64

# %%
sales['Sub-Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: >
